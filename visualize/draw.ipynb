# %%
from matplotlib import pyplot as plt
import numpy as np
# l_joint_pretrain= plt.errorbar(x, pretrain_joint_y, yerr=pretrain_joint_std,fmt='o-',color='gold')
# l_multi_bn_pretrain = plt.errorbar(x, pretrain_multi_bn_y, yerr=pretrain_multi_bn_std,fmt='o-',color='red')
# l_multi_bn_fix_pretrain = plt.errorbar(x, pretrain_multi_bn_fix_y, yerr=pretrain_multi_bn_fix_std,fmt='o-',color='dimgray')
# l_rwalk_pretrain = plt.errorbar(x, pretrain_rwalk_y, yerr=pretrain_rwalk_std,fmt='o-',color='aqua')
# l_mas_pretrain = plt.errorbar(x, pretrain_mas_y, yerr=pretrain_mas_std,fmt='o-',color='aquamarine')
# l_ewc_pretrain= plt.errorbar(x, pretrain_ewc_y, yerr=pretrain_ewc_std,fmt="o-",color='hotpink')
# l_single_bn_pretrain=plt.errorbar(x, pretrain_sing_bn_y, yerr=pretrain_sing_bn_std,fmt="o-",color='lightgreen')
# l_finetune_pretrain= plt.errorbar(x, pretrain_finetune_y, yerr=pretrain_finetune_std,fmt='o-',color='purple')

# l_joint_no_pretrain= plt.errorbar(x, no_pretrain_joint_y, yerr=no_pretrain_joint_std,fmt='o-',color='black')
# l_multi_bn_no_pretrain = plt.errorbar(x, no_pretrain_multi_bn_y, yerr=no_pretrain_multi_bn_std,fmt='o-',color='olive')
# l_rwalk_no_pretrain = plt.errorbar(x, no_pretrain_rwalk_y, yerr=no_pretrain_rwalk_std,fmt='o-',color='blue')
# l_mas_no_pretrain = plt.errorbar(x, no_pretrain_mas_y, yerr=no_pretrain_mas_std,fmt='o-',color='blueviolet')
# l_ewc_no_pretrain= plt.errorbar(x, no_pretrain_ewc_y, yerr=no_pretrain_ewc_std,fmt="o-",color='brown')
# l_single_bn_no_pretrain=plt.errorbar(x, no_pretrain_sing_bn_y, yerr=no_pretrain_sing_bn_std,fmt="o-",color='burlywood')
# l_finetune_no_pretrain= plt.errorbar(x, no_pretrain_finetune_y, yerr=no_pretrain_finetune_std,fmt="o-",color='cadetblue')

# %%
x = list(range(1, 12))
joint_no_pretrain = [67.3, 69.728, 71.332, 72.538, 74.002, 75.266, 76.562, 77.704, 78.554, 79.262, 80.66666667]
joint_no_pretrain_std = [2.307596152, 2.416644368, 2.212559604, 2.047833001, 2.162329762, 2.24137904, 2.24069632, 2.176058363, 2.260968819, 1.981027511, 2.753785274]

print(len(x))
print(len(joint_no_pretrain))

multi_bn_no_pretrain = [67.3, 69.728, 71.166, 72.076, 73.214, 73.934, 75.126, 75.882, 76.778, 77.422, 78.08333333]
multi_bn_no_pretrain_std = [2.307596152, 2.374862101, 2.307266781, 1.690008876, 1.73021097, 1.255479988, 1.242670511, 1.334567346, 1.526194614, 1.331885881, 2.376096238]

lwf_no_pretrain = [67.3, 68.726, 69.25, 68.154, 69.214, 70.4, 69.874, 69.352, 68.832, 69.582, 69.08333333]
lwf_no_pretrain_std = [3.438749773, 2.43474434, 3.350477578, 2.024766653, 3.921546889, 3.113591174, 2.926256995, 4.022992667, 2.801092644, 2.649484856, 2.268442931]

mas_no_pretrain = [66.1, 59.726, 63.502, 56.922, 65.356, 67.466, 63.75, 66.704, 68.166, 70.788, 71.16666667]
mas_no_pretrain_std = [2.559296778, 5.278657973, 3.124479157, 1.307811148, 5.20584095, 4.382314457, 3.678858519, 7.236285649, 3.683887892, 2.888930598, 4.625563029]

ewc_no_pretrain = [67.9, 62.272, 65.666, 60.924, 67.57, 69.732, 63.936, 67.234, 69.278, 71.21, 70.08333333]
ewc_no_pretrain_std = [3.577708764, 3.664917462, 3.419573073, 2.046235568, 5.159917635, 4.065602046, 3.734177286, 7.900761356, 2.78367922, 2.094612136, 8.412540243]

rwalk_no_pretrain = [67.3, 62.636, 66.5, 60, 66.928, 70.332, 66.5, 69.47, 69.388, 74.474, 73.08333333]
rwalk_no_pretrain_std = [2.307596152, 3.711459282, 1.684903558, 1.78409641, 5.453720748, 3.061228512, 4.420390254, 6.288398047, 4.362919894, 1.685120174, 6.027713773]

finetune_no_pretrain = [67.3, 61.274, 62.67, 57.92, 62.502, 64.468, 59.44, 63.766, 62.666, 64.63, 63.25]
finetune_no_pretrain_std = [2.307596152, 2.754764963, 5.405437078, 4.226677182, 5.960756663, 4.245664848, 4.75768326, 3.324339032, 3.441079772, 5.165428346, 8.627716963]

l_joint_no_pretrain= plt.errorbar(x, joint_no_pretrain, yerr=joint_no_pretrain_std,fmt='o-',color='black')
l_multi_bn_no_pretrain = plt.errorbar(x, multi_bn_no_pretrain, yerr=multi_bn_no_pretrain_std,fmt='o-',color='olive')
l_lwf_no_pretrain = plt.errorbar(x, lwf_no_pretrain, yerr=lwf_no_pretrain_std,fmt='o-',color='dodgerblue')
l_rwalk_no_pretrain = plt.errorbar(x, rwalk_no_pretrain, yerr=rwalk_no_pretrain_std,fmt='o-',color='blue')
l_mas_no_pretrain = plt.errorbar(x, mas_no_pretrain, yerr=mas_no_pretrain_std,fmt='o-',color='blueviolet')
l_ewc_no_pretrain = plt.errorbar(x, ewc_no_pretrain, yerr=ewc_no_pretrain_std,fmt='o-',color='brown')
l_finetune_no_pretrain= plt.errorbar(x, finetune_no_pretrain, yerr=finetune_no_pretrain_std,fmt="o-",color='cadetblue')

plt.legend(handles=[l_joint_no_pretrain, l_multi_bn_no_pretrain, l_rwalk_no_pretrain, l_mas_no_pretrain, l_ewc_no_pretrain, l_lwf_no_pretrain, l_finetune_no_pretrain],
    labels=['Joint', 'Multi bn', 'RWALK', 'MAS', 'EWC', 'LwF', 'Finetune'], loc='best')

y_ticks = np.arange(50, 101, 10)
plt.xticks(x)
plt.yticks(y_ticks)

# plt.xlim((49, 101))
plt.ylim((50, 101))

plt.title('Base 20 Increment 2 (skin40 no pretrained)')

plt.xlabel('Number of Tasks')
plt.ylabel('MCR')

plt.savefig('./skin40_b2i2_no_pretrain.png')
plt.show()
# Out:
# 11
# 11
