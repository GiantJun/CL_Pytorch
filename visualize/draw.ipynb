# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
# CIFAR100 5阶段

x = list(range(20, 120, 20))


icarl = [92.68333333,	87.3,	81.24,	72.78666667,	66.81666667]

dynamic_er = [93.1,	87.00666667,	79.95333333,	74.05333333,	69.75666667]

wa = [93.3,	85.71333333,	79.90333333,	74.14333333,	69.58666667]


ours = [92.31666667,	85.53666667,	80.61,	76.82,	73.19]

lucir = [92.98333333,	83.11333333,	77.56,	72.66333333,	68.97666667]

podnet = [92.8,	81.67,	74.55,	69.65333333,	64.22666667]

der_pp = [93.65,	87.23,	80.48333333,	74.32,	69.62333333]


icarl_pretrain_std = [0.246644143,	0.589491306,	0.421544778,	0.092376043,	0.117189306]

dynamic_er_pretrain_std = [0.377491722,	0.366787859,	0.531632705,	0.571430952,	0.587565599]

wa_pretrain_std = [0.435889894,	0.200333056,	0.204042479,	0.09504385,	0.100166528]


ours_pretrain_std = [0.160727513,	0.169213869,	0.060827625,	0.087177979,	0.266270539]

lucir_pretrain_std = [0.404145188,	0.310053759,	0.51507281,	0.047258156,	0.133166562]

podnet_pretrain_std = [0.05,	0.276224546,	0.445421149,	0.260064095,	0.181475435]

der_pp_pretrain_std = [0.132287566,	0.259422435,	0.772161468,	0.421544778,	1.104370107]


plt.figure(figsize=(3, 2), dpi=300) # default figsize=(6.4, 4.8), dpi=100



joint = plt.errorbar(x[-1], 79.08, fmt='x', color='black', linewidth=1, markersize=3)
ours_curve= plt.errorbar(x, ours,yerr=ours_pretrain_std, fmt='.-', color='red', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
icar_curve = plt.errorbar(x, icarl, yerr=icarl_pretrain_std, fmt='.-',color='dodgerblue', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
dynamic_er_curve = plt.errorbar(x, dynamic_er, yerr=dynamic_er_pretrain_std, fmt='.-', color='green', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
der_pp_curve = plt.errorbar(x, der_pp, yerr=der_pp_pretrain_std, fmt='.-', color='orange', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
wa_curve = plt.errorbar(x, wa, yerr=wa_pretrain_std, fmt='.-', color='m', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
lucir_curve = plt.errorbar(x, lucir, yerr=lucir_pretrain_std, fmt='.-', color='sienna', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
podnet_curve = plt.errorbar(x, podnet, yerr=podnet_pretrain_std, fmt='.-', color='mediumblue', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)

plt.legend(handles=[joint, ours_curve, lucir_curve,  icar_curve, dynamic_er_curve,der_pp_curve, podnet_curve, wa_curve],
    labels=['Upbound', 'ACL(ours)', 'UCIR',  'iCaRL', 'DynaER','DER++', 'PODNet', 'WA'], bbox_to_anchor=(0, 0),fontsize=5 ,loc=3, borderaxespad=0)



y_ticks = np.arange(40, 101, 10)

plt.xticks(x, fontsize=8)
plt.yticks(y_ticks, fontsize=8)


plt.grid(ls='--', c='gray', axis='y') # linewidth=2

# plt.xlim((49, 101))
plt.ylim((40, 101))

# plt.title('Base 2 Increment 2 (skin8 buffer80)')

plt.xlabel('Number of classs', fontsize=8)
# plt.ylabel('MCR', fontsize=8)

plt.savefig('./cifar100_b0i20_v2.png', bbox_inches='tight')

plt.show()

# plt.xlabel('Number of classs', fontsize=8)
# plt.ylabel('MCR', fontsize=8)

# %%
# CIFAR100 10阶段

x = list(range(10, 110, 10))


icarl = [96.9,	90.68333333,	88.37666667,	80.93666667,	76.93333333,	73.25666667,	68.78333333,	63.33666667,	60.43333333	,57.74666667]

dynamic_er = [97.23333333,	90.78333333,	87.89,	83.06,	78.28666667,	75.55666667	,73.51666667,	68.43,	66.19333333,	64.97]

wa = [96.66666667,	90.18333333,	85.99,	80.97333333,	76.24666667,	73.43333333,	70.56666667,	64.75,	62.17333333,	60]


ours = [97.03333333,	90.58333333,	88.23333333,	84.68,	81.86666667,	80.37333333,	79.10333333,	75.99333333,	74.09,	73.02333333]

lucir = [96.93333333,	86.91666667,	83.1,	78.97333333,	74.74666667,	72.45666667,	71.51,	68.42666667	,67.26666667,	65.99333333]

podnet = [96.6,	83.78333333,	80.92,	77.32333333,	73.6,	70.01,	67.71,	64.09666667,	60.91666667,	58.96333333]

der_pp = [97.43333333,	91.6,	88.85666667,	84.50666667,	80.06666667,	76.21333333,	75.90666667,	70.33,	67.46,	66.69]

icarl_pretrain_std = [0.173205081,	0.596517672,	0.080829038,	0.318799833,	0.391066917,	0.60583276,	0.430619708,	0.263881286,	0.354447928,	0.352325607]

dynamic_er_pretrain_std = [0.057735027,	0.236290781,	0.155884573,	0.300499584,	0.266333125	,0.723901467,	0.325781113,	0.840416563,	0.66252044,	0.679485099]

wa_pretrain_std = [0.585946528,	1.331665624,	1.353994092,	1.065191689,	0.33724373,	0.532666249	,0.696156113,	0.888425574,	0.440492149,	1.105033936]


ours_pretrain_std = [0.057735027,	0.604841577,	0.513160144,	0.367151195,	0.355715242,	0.315647483,	0.597438979,	0.549302588,	0.693757883,	0.465761026]

lucir_pretrain_std = [0.321455025,	0.464578662,	0.468934964,	0.611991285,	0.555817716,	0.438900141,	0.62960305,	0.686318682,	1.009273666,	0.598108128]

podnet_pretrain_std = [0.435889894,	0.637050495,	0.776723889,	0.847132418,	0.373630834	,0.435545635	,0.244335834	,0.478574271	,0.358375966	,0.583980593]

der_pp_pretrain_std = [0.251661148,	0.304138127,	0.56092186,	0.56092186,	0.60044428,	0.60797478,	0.693277241,	0.629523629,	0.976882797,	0.542862782]

plt.figure(figsize=(3, 2), dpi=300) # default figsize=(6.4, 4.8), dpi=100



joint = plt.errorbar(x[-1], 79.08, fmt='x', color='black', linewidth=1, markersize=3)
ours_curve= plt.errorbar(x, ours,yerr=ours_pretrain_std, fmt='.-', color='red', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
icar_curve = plt.errorbar(x, icarl, yerr=icarl_pretrain_std, fmt='.-',color='dodgerblue', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
dynamic_er_curve = plt.errorbar(x, dynamic_er, yerr=dynamic_er_pretrain_std, fmt='.-', color='green', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
der_pp_curve = plt.errorbar(x, der_pp, yerr=der_pp_pretrain_std, fmt='.-', color='orange', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
wa_curve = plt.errorbar(x, wa, yerr=wa_pretrain_std, fmt='.-', color='m', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
lucir_curve = plt.errorbar(x, lucir, yerr=lucir_pretrain_std, fmt='.-', color='sienna', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
podnet_curve = plt.errorbar(x, podnet, yerr=podnet_pretrain_std, fmt='.-', color='mediumblue', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)

plt.legend(handles=[joint, ours_curve, lucir_curve,  icar_curve, dynamic_er_curve,der_pp_curve, podnet_curve, wa_curve],
    labels=['Upbound', 'ACL(ours)', 'UCIR',  'iCaRL', 'DynaER','DER++', 'PODNet', 'WA'], bbox_to_anchor=(0, 0),fontsize=5 ,loc=3, borderaxespad=0)



y_ticks = np.arange(40, 101, 10)

plt.xticks(x, fontsize=8)
plt.yticks(y_ticks, fontsize=8)


plt.grid(ls='--', c='gray', axis='y') # linewidth=2

# plt.xlim((49, 101))
plt.ylim((40, 101))

# plt.title('Base 2 Increment 2 (skin8 buffer80)')

plt.xlabel('Number of classs', fontsize=8)
# plt.ylabel('MCR', fontsize=8)

plt.savefig('./cifar100_b0i10_v2.png', bbox_inches='tight')

plt.show()

# %%
# skin8 buffer=40

x = list(range(2, 10, 2))


icarl = [94.23,	65.948,	46.528,	41.942]

dynamic_er = [95.222,	63.22,	43.056,	39.472]

wa = [94.326,	58.59,	36.398,	30.65]


ours = [94.742,	70.128,	52.01,	50.688]

lucir = [95.13666667,	65.51666667,	46.85,	43.78]

podnet = [94.92333333,	59.96333333,	43.34,	31.80333333]

der_pp = [94.0575,	65.4575,	43.335,	30.6725]


icarl_pretrain_std = [1.254750971,	1.427592379,	1.583136128,	1.481796207]

dynamic_er_pretrain_std = [1.133631333,	1.757270611,	1.378959753,	2.398597507]

wa_pretrain_std = [0.930204279,	2.089772715,	1.664097353,	0.57497826]


ours_pretrain_std = [1.144866804,	2.070173906,	1.254731047,	3.059398634]

lucir_pretrain_std = [1.634299034,	1.217223617,	1.385965368,	1.551998711]

podnet_pretrain_std = [1.955232297,	0.9579318,	0.081853528,	1.175471537]

der_pp_pretrain_std = [0.899828687,	1.748492208,	1.84408062,	0.839816448]


plt.figure(figsize=(3, 2), dpi=300) # default figsize=(6.4, 4.8), dpi=100



joint = plt.errorbar(x[-1], 70.37666667, fmt='x', color='black', linewidth=1, markersize=3)
ours_curve= plt.errorbar(x, ours,yerr=ours_pretrain_std, fmt='.-', color='red', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
icar_curve = plt.errorbar(x, icarl, yerr=icarl_pretrain_std, fmt='.-',color='dodgerblue', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
dynamic_er_curve = plt.errorbar(x, dynamic_er, yerr=dynamic_er_pretrain_std, fmt='.-', color='green', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
der_pp_curve = plt.errorbar(x, der_pp, yerr=der_pp_pretrain_std, fmt='.-', color='orange', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
wa_curve = plt.errorbar(x, wa, yerr=wa_pretrain_std, fmt='.-', color='m', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
lucir_curve = plt.errorbar(x, lucir, yerr=lucir_pretrain_std, fmt='.-', color='sienna', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
podnet_curve = plt.errorbar(x, podnet, yerr=podnet_pretrain_std, fmt='.-', color='mediumblue', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)

plt.legend(handles=[joint, ours_curve, lucir_curve,  icar_curve, dynamic_er_curve,der_pp_curve, podnet_curve, wa_curve],
    labels=['Upbound', 'ACL(ours)', 'UCIR',  'iCaRL', 'DynaER','DER++', 'PODNet', 'WA'], bbox_to_anchor=(0, 0),fontsize=5 ,loc=3, borderaxespad=0)



y_ticks = np.arange(20, 101, 10)
# x_ticks = ['LY', 'CO','BR','CP', 'LU','OR','ST']
plt.xticks(x, fontsize=8)
plt.yticks(y_ticks, fontsize=8)


plt.grid(ls='--', c='gray', axis='y') # linewidth=2

# plt.xlim((49, 101))
plt.ylim((20, 101))

# plt.title('Base 2 Increment 2 (skin8 buffer80)')

plt.xlabel('Number of classs', fontsize=8)
plt.ylabel('MCR (%)', fontsize=8)

plt.savefig('./skin8_b0i2_buffer40_v2.png', bbox_inches='tight')

plt.show()

# plt.xlabel('Number of classs', fontsize=8)
# plt.ylabel('MCR', fontsize=8)

# %%
# skin8 buffer=16

x = list(range(2, 10, 2))


icarl = [94.134,	60.386,	40.864,	34.366]

dynamic_er = [94.968,	59.742,	40.982,	36.544]

wa = [94.326,	51.778,	30.214,	24.806]


ours = [94.742,	65.288,	49.412,	45.97]

lucir = [94.134,	63.558,	45.32,	40.8]

podnet = [95.544,	57.598,	41.538,	30.48]

der_pp = [93.94333333,	59.16333333,	38.28333333,	25.34333333]


icarl_pretrain_std = [1.302796991,	1.841352764,	2.627552093,	1.283619881]

dynamic_er_pretrain_std = [2.041768841,	1.843222721,	2.518644477,	2.710023985]

wa_pretrain_std = [0.930204279,	1.894840363,	0.483766473,	0.448084813]


ours_pretrain_std = [1.144866804,	2.712170717,	1.035335694,	3.707580073]

lucir_pretrain_std = [1.961550407,	2.798145815,	1.922745433,	2.466779277]

podnet_pretrain_std = [1.394912184,	2.742894457,	1.75363052,	3.032037269]

der_pp_pretrain_std = [0.808290377,	0.71988425,	2.702708518,	2.218114815]


plt.figure(figsize=(3, 2), dpi=300) # default figsize=(6.4, 4.8), dpi=100



joint = plt.errorbar(x[-1], 70.37666667, fmt='x', color='black', linewidth=1, markersize=3)
ours_curve= plt.errorbar(x, ours,yerr=ours_pretrain_std, fmt='.-', color='red', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
icar_curve = plt.errorbar(x, icarl, yerr=icarl_pretrain_std, fmt='.-',color='dodgerblue', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
dynamic_er_curve = plt.errorbar(x, dynamic_er, yerr=dynamic_er_pretrain_std, fmt='.-', color='green', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
der_pp_curve = plt.errorbar(x, der_pp, yerr=der_pp_pretrain_std, fmt='.-', color='orange', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
wa_curve = plt.errorbar(x, wa, yerr=wa_pretrain_std, fmt='.-', color='m', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
lucir_curve = plt.errorbar(x, lucir, yerr=lucir_pretrain_std, fmt='.-', color='sienna', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
podnet_curve = plt.errorbar(x, podnet, yerr=podnet_pretrain_std, fmt='.-', color='mediumblue', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)

plt.legend(handles=[joint, ours_curve, lucir_curve,  icar_curve, dynamic_er_curve,der_pp_curve, podnet_curve, wa_curve],
    labels=['Upbound', 'ACL', 'UCIR',  'iCaRL', 'DynaER','DER++', 'PODNet', 'WA'], bbox_to_anchor=(0, 0),fontsize=5 ,loc=3, borderaxespad=0)



y_ticks = np.arange(20, 101, 10)
# x_ticks = ['LY', 'CO','BR','CP', 'LU','OR','ST']
plt.xticks(x, fontsize=8)
plt.yticks(y_ticks, fontsize=8)


plt.grid(ls='--', c='gray', axis='y') # linewidth=2

# plt.xlim((49, 101))
plt.ylim((20, 101))

# plt.title('Base 2 Increment 2 (skin8 buffer80)')

plt.xlabel('Number of classs', fontsize=8)
plt.ylabel('MCR (%)', fontsize=8)

plt.savefig('./skin8_b0i2_buffer16_v2.png', bbox_inches='tight')

plt.show()

# plt.xlabel('Number of classs', fontsize=8)
# plt.ylabel('MCR', fontsize=8)

# %%
# p16 order1

order_label=['CO', 'LU', 'LY', 'ST', 'OR','CP', 'BT']
x = list(range(1, 8))

der_pp = [100,	99.55,	81.798,	62.442,	61.722,	59.704,	57.824]
der_pp_pretrain_std = [0,	0.480884602,	1.303138519,	1.873171108,	1.6080796,	0.738532328,	1.741818016]

ours = [100, 99.85, 84.536, 68.54, 71.17, 71.67, 72.482]
ours_std = [0, 0.223606798, 0.299633109, 0.38340579, 0.411643049, 0.9750641, 1.195708995]

dynamic_er = [100, 99.5, 84.102, 67.35, 68.3, 68.87, 69.346]
dynamic_er_std = [0, 0.395284708, 0.691462219, 1.155876291, 0.809506022, 0.533526007, 0.757647675]

icarl = [100, 99.75, 83.566, 67.068, 67.704, 66.154, 65.662]
icarl_std = [0, 0.353553391, 0.190341798, 0.508645259, 1.236559744, 1.367983918, 0.297942948]

wa = [100, 99.7, 83.668, 65.004, 64.656, 61.42, 59.278]
wa_std = [0, 0.273861279, 0.850658568, 0.800893251, 3.330860249, 2.313363352, 1.592048994]

lucir = [100, 98.08333333, 82.44333333, 63.98666667, 64.29, 59.3, 57.43666667]
lucir_std = [0, 1.376892637, 1.130722483, 0.398789836, 1.277380131, 1.282926342, 1.473578411]

podnet = [100, 99, 81.94333333, 58.36, 58.21666667, 55.08333333, 54.03333333]
podnet_std = [0, 0.433012702, 0.196299092, 1.095764573, 1.463158684, 1.417826976, 1.692168234]

plt.figure(figsize=(3, 2), dpi=300) # default figsize=(6.4, 4.8), dpi=100

joint = plt.errorbar(x[-1], 74.55, fmt='x', color='black', linewidth=1, markersize=3)
ours_curve= plt.errorbar(x, ours,yerr=ours_std, fmt='.-', color='red', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
icar_curve = plt.errorbar(x, icarl, yerr=icarl_std, fmt='.-',color='dodgerblue', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
dynamic_er_curve = plt.errorbar(x, dynamic_er, yerr=dynamic_er_std, fmt='.-', color='green', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
der_pp_curve = plt.errorbar(x, der_pp, yerr=der_pp_pretrain_std, fmt='.-', color='orange', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
wa_curve = plt.errorbar(x, wa, yerr=wa_std, fmt='.-', color='m', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
lucir_curve = plt.errorbar(x, lucir, yerr=lucir_std, fmt='.-', color='sienna', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
podnet_curve = plt.errorbar(x, podnet, yerr=podnet_std, fmt='.-', color='mediumblue', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)

plt.legend(handles=[joint, ours_curve, lucir_curve,  icar_curve, dynamic_er_curve,der_pp_curve, podnet_curve, wa_curve],
    labels=['Upbound', 'ACL', 'UCIR',  'iCaRL', 'DynaER', 'DER++', 'PODNet', 'WA'], bbox_to_anchor=(0, 0),fontsize=5 ,loc=3, borderaxespad=0)

y_ticks = np.arange(40, 101, 10)
plt.xticks(x, order_label, fontsize=8)
plt.yticks(y_ticks, fontsize=8)

plt.grid(ls='--', c='gray', axis='y') # linewidth=2

# plt.xlim((49, 101))
plt.ylim((40, 101))

# plt.title('Base 2 Increment 2 (skin8 buffer80)')

plt.xlabel('Task order', fontsize=8)
# plt.ylabel('ACC (%)')

plt.savefig('./p16_order4_buffer80.png', bbox_inches='tight')
plt.show()

# %%
# p16 order2

order_label=['CP', 'BR', 'OR', 'LY', 'ST','LU', 'CO']
x = list(range(1, 8))

ours = [82.5, 83.3, 84.766, 76.602, 65.27, 70.306, 73.244]
ours_std = [2, 1.662077014, 1.287722796, 1.020940743, 1.547611062, 0.376404038, 0.282718942]

der_pp = [81,	79.75,	78.032,	65.024,	53.752,	56.062,	56.864]
der_pp_pretrain_std = [2.179449472,	2.157834563,	3.287874693,	2.252582962,	3.010725826,	1.275507742,	2.42080152]

dynamic_er = [82, 82.15, 83.6, 74.474, 61.642, 67.392, 69.87]
dynamic_er_std = [1.414213562, 0.840386816, 0.933488082, 0.135572859, 1.015317684, 0.948324839, 0.69710114]

icarl = [81.7, 79.4, 80.834, 70.924, 59.868, 62.046, 65.59]
icarl_std = [0, 0.353553391, 0.190341798, 0.508645259, 1.236559744, 1.367983918, 0.297942948]

wa = [84.3, 76.75, 77.634, 63.426, 50.338, 55.664, 57.986]
wa_std = [1.440486029, 2.883140649, 1.108706453, 1.737060736, 1.952401086, 1.315838136, 1.570200624]

lucir = [82.4, 69.4, 76.8, 63.9, 51.066, 52.468, 54.562]
lucir_std = [1.47478812, 5.729856019, 1.947292993, 2.765583121, 1.999594959, 4.105918898, 3.778434861]

podnet = [85, 77.375, 73.625, 61.0325, 49.96, 54.8675, 56.955]
podnet_std = [1.224744871, 2.453738644, 2.116230926, 1.092622991, 1.980740602, 1.908793249, 1.302318445]

plt.figure(figsize=(3, 2), dpi=300) # default figsize=(6.4, 4.8), dpi=100

joint = plt.errorbar(x[-1], 74.55, fmt='x', color='black', linewidth=1, markersize=3)
ours_curve= plt.errorbar(x, ours,yerr=ours_std, fmt='.-', color='red', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
icar_curve = plt.errorbar(x, icarl, yerr=icarl_std, fmt='.-',color='dodgerblue', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
dynamic_er_curve = plt.errorbar(x, dynamic_er, yerr=dynamic_er_std, fmt='.-', color='green', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
der_pp_curve = plt.errorbar(x, der_pp, yerr=der_pp_pretrain_std, fmt='.-', color='orange', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
wa_curve = plt.errorbar(x, wa, yerr=wa_std, fmt='.-', color='m', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
lucir_curve = plt.errorbar(x, lucir, yerr=lucir_std, fmt='.-', color='sienna', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
podnet_curve = plt.errorbar(x, podnet, yerr=podnet_std, fmt='.-', color='mediumblue', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)

plt.legend(handles=[joint, ours_curve, lucir_curve,  icar_curve, dynamic_er_curve,der_pp_curve, podnet_curve, wa_curve],
    labels=['Upbound', 'ACL', 'UCIR',  'iCaRL', 'DynaER', 'DER++', 'PODNet', 'WA'], bbox_to_anchor=(0, 0),fontsize=5 ,loc=3, borderaxespad=0)

y_ticks = np.arange(40, 101, 10)
plt.xticks(x, order_label, fontsize=8)
plt.yticks(y_ticks, fontsize=8)

plt.grid(ls='--', c='gray', axis='y') #, fontsize=8 linewidth=2

# plt.xlim((49, 101))
plt.ylim((40, 101))

# plt.title('Base 2 Increment 2 (skin8 buffer80)')

plt.xlabel('Task order', fontsize=8)
# plt.ylabel('MCR (%)', fontsize=8)

plt.savefig('./p16_order5_buffer80.png', bbox_inches='tight')
plt.show()

# %%
# MedMNIST 

order_label=['BloodMNIST', 'OrganaMNIST', 'PathMNIST', 'TissueMNIST']
x = list(range(1, 5))

ours = [95.05,	94.06666667, 92.91333333,	69.33666667]
ours_std = [0.404474968,	0.447697815,	0.101159939,	0.372871738]

der_pp = [95.46,	94.17,	84.43,	57.33333333]
der_pp_pretrain_std = [0.415812458,	0.127671453,	2.504855285,	1.633534001]

dynamic_er = [95.39,	92.26,	84.37,	50.708]
dynamic_er_std = [0.340807864,	0.749733286,	2.051121644,	2.044986553]

icarl = [96.612,	94.13,	83.462,	55.454]
icarl_std = [0.363276754,	0.571576766,	3.495507116,	1.022169262]

# wa = [95.87,	94.24333333,	78.36,	12.02666667]
# wa_std = [0.445421149,	0.148436294,	3.615978429,	2.33017882]

lucir = [94.03666667,	89.45666667,	87.4,	66.36666667]
lucir_std = [0.6132971,	1.576779418,	0.792653771,	0.420277686]

podnet = [95.57666667,	76.75333333,	71.45666667,	52.84]
podnet_std = [0.220302822,	3.107158402,	2.759462508,	2.436165019]

plt.figure(figsize=(3, 2), dpi=300) # default figsize=(6.4, 4.8), dpi=100

joint = plt.errorbar(x[-1], 74.66, fmt='x', color='black', linewidth=1, markersize=3)
ours_curve= plt.errorbar(x, ours,yerr=ours_std, fmt='.-', color='red', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
icar_curve = plt.errorbar(x, icarl, yerr=icarl_std, fmt='.-',color='dodgerblue', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
dynamic_er_curve = plt.errorbar(x, dynamic_er, yerr=dynamic_er_std, fmt='.-', color='green', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
der_pp_curve = plt.errorbar(x, der_pp, yerr=der_pp_pretrain_std, fmt='.-', color='orange', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
# wa_curve = plt.errorbar(x, wa, yerr=wa_std, fmt='.-', color='m', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
lucir_curve = plt.errorbar(x, lucir, yerr=lucir_std, fmt='.-', color='sienna', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)
podnet_curve = plt.errorbar(x, podnet, yerr=podnet_std, fmt='.-', color='mediumblue', linewidth=1, markersize=3, elinewidth=1, capthick=1, capsize=1)

plt.legend(handles=[joint, ours_curve, lucir_curve,  icar_curve, dynamic_er_curve,der_pp_curve, podnet_curve],
    labels=['Upbound', 'ACL(ours)', 'UCIR',  'iCaRL', 'DynaER', 'DER++', 'PODNet'], bbox_to_anchor=(0, 0),fontsize=5 ,loc=3, borderaxespad=0)

y_ticks = np.arange(40, 101, 10)
plt.xticks(x, order_label, fontsize=6)
plt.yticks(y_ticks, fontsize=6)

plt.grid(ls='--', c='gray', axis='y') #, fontsize=8 linewidth=2

# plt.xlim((49, 101))
plt.ylim((40, 101))

# plt.title('Base 2 Increment 2 (skin8 buffer80)')

plt.xlabel('Domains', fontsize=8)
plt.ylabel('MCR (%)', fontsize=8)

plt.savefig('./domains.png', bbox_inches='tight')
plt.show()
